# %%
import numpy as np
import h5py
import bacco
import matplotlib.pyplot as plt
import dask.array as dd

# %%
import os
os.chdir("/lscratch/fgmaion/MTNG-resims/src")
import utils

# %%
base = "/cosmos_storage/data_sharing/tmp_resims/1080-A/output_ics/snapdir_000/"
zoom = utils.read_zoom(base=base)
# Out:
# Read data for 0/1314118 1314118/0 799866/1150 particles...
# Read data for 0/1314118 1314118/0 799866/1264 particles...
# Read data for 0/1314118 1314118/0 799866/1434 particles...
# Read data for 168912/1314118 1314118/104409 799866/24980 particles...
# Read data for 168912/1314118 1314118/104409 799866/25164 particles...
# Read data for 168912/1314118 1314118/104409 799866/25355 particles...
# Read data for 168912/1314118 1314118/104409 799866/25385 particles...
# Read data for 168912/1314118 1314118/104409 799866/25513 particles...
# Read data for 168912/1314118 1314118/104409 799866/25984 particles...
# Read data for 168912/1314118 1314118/104409 799866/26315 particles...
# Read data for 168912/1314118 1314118/104409 799866/26408 particles...
# Read data for 168912/1314118 1314118/104409 799866/26508 particles...
# Read data for 168912/1314118 1314118/104409 799866/26601 particles...
# Read data for 168912/1314118 1314118/104409 799866/30264 particles...
# Read data for 168912/1314118 1314118/104409 799866/30504 particles...
# Read data for 464255/1314118 1314118/294888 799866/75169 particles...
# Read data for 464255/1314118 1314118/294888 799866/75255 particles...
# Read data for 464255/1314118 1314118/294888 799866/75439 particles...
# Read data for 464255/1314118 1314118/294888 799866/76064 particles...
# Read data for 741483/1314118 1314118/471964 799866/115740 particles...
# Read data for 741483/1314118 1314118/471964 799866/116512 particles...
# Read data for 741483/1314118 1314118/471964 799866/117375 particles...
# Read data for 1064568/1314118 1314118/626164 799866/151041 particles...
# Read data for 1064568/1314118 1314118/626164 799866/151358 particles...
# Read data for 1064568/1314118 1314118/626164 799866/151780 particles...
# Read data for 1064568/1314118 1314118/626164 799866/151992 particles...
# Read data for 1314118/1314118 1314118/799866 799866/193464 particles...
# Read data for 1314118/1314118 1314118/799866 799866/193634 particles...
# Read data for 1314118/1314118 1314118/799866 799866/193986 particles...
# Read data for 1314118/1314118 1314118/799866 799866/194618 particles...
# Read data for 1314118/1314118 1314118/799866 799866/195180 particles...
# Read data for 1314118/1314118 1314118/799866 799866/195280 particles...

# %%
fig, ax = plt.subplots(1, 3, dpi=100, figsize=(15,5))

ax[0].scatter(zoom['pos3'][:,0], zoom['pos3'][:,1], marker='.', s=0.0005, color='C3')
ax[0].scatter(zoom['pos2'][:,0], zoom['pos2'][:,1], marker='.', s=0.0005, color='C2')
ax[0].scatter(zoom['pos1'][:,0], zoom['pos1'][:,1], marker='.', s=0.0005, color='C0')

ax[0].set_xlabel('$x[$Mpc$/h]$', fontsize=16)
ax[0].set_ylabel('$y[$Mpc$/h]$', fontsize=16)

ax[1].scatter(zoom['pos3'][:,0], zoom['pos3'][:,2], marker='.', s=0.0005, color='C3')
ax[1].scatter(zoom['pos2'][:,0], zoom['pos2'][:,2], marker='.', s=0.0005, color='C2')
ax[1].scatter(zoom['pos1'][:,0], zoom['pos1'][:,2], marker='.', s=0.0005, color='C0')

ax[1].set_xlabel('$x[$Mpc$/h]$', fontsize=16)
ax[1].set_ylabel('$z[$Mpc$/h]$', fontsize=16)

ax[2].scatter(zoom['pos3'][:,1], zoom['pos3'][:,2], marker='.', s=0.0005, color='C3')
ax[2].scatter(zoom['pos2'][:,1], zoom['pos2'][:,2], marker='.', s=0.0005, color='C2')
ax[2].scatter(zoom['pos1'][:,1], zoom['pos1'][:,2], marker='.', s=0.0005, color='C0')

ax[2].set_xlabel('$y[$Mpc$/h]$', fontsize=16)
ax[2].set_ylabel('$z[$Mpc$/h]$', fontsize=16)
# Out:
# Text(0, 0.5, '$z[$Mpc$/h]$')

# %%
base = "/cosmos_storage/data_sharing/tmp_resims/1080-A/output_ics_domainshift/snapdir_000/"
zoom = utils.read_zoom(base=base)
# Out:
# Read data for 0/1314118 1314118/0 797414/163 particles...
# Read data for 0/1314118 1314118/0 797414/403 particles...
# Read data for 0/1314118 1314118/0 797414/1420 particles...
# Read data for 0/1314118 1314118/0 797414/1562 particles...
# Read data for 273267/1314118 1314118/152176 797414/33260 particles...
# Read data for 273267/1314118 1314118/152176 797414/33458 particles...
# Read data for 273267/1314118 1314118/152176 797414/33950 particles...
# Read data for 765264/1314118 1314118/409172 797414/89956 particles...
# Read data for 765264/1314118 1314118/409172 797414/92072 particles...
# Read data for 765264/1314118 1314118/409172 797414/92403 particles...
# Read data for 765264/1314118 1314118/409172 797414/92825 particles...
# Read data for 765264/1314118 1314118/409172 797414/92967 particles...
# Read data for 765264/1314118 1314118/409172 797414/93032 particles...
# Read data for 765264/1314118 1314118/409172 797414/93314 particles...
# Read data for 931086/1314118 1314118/515120 797414/118307 particles...
# Read data for 1014814/1314118 1314118/582044 797414/136725 particles...
# Read data for 1014814/1314118 1314118/582044 797414/137560 particles...
# Read data for 1014814/1314118 1314118/582044 797414/139417 particles...
# Read data for 1014814/1314118 1314118/582044 797414/139559 particles...
# Read data for 1014814/1314118 1314118/582044 797414/139806 particles...
# Read data for 1014814/1314118 1314118/582044 797414/139878 particles...
# Read data for 1014814/1314118 1314118/582044 797414/139964 particles...
# Read data for 1014814/1314118 1314118/582044 797414/140631 particles...
# Read data for 1014814/1314118 1314118/582044 797414/140808 particles...
# Read data for 1014814/1314118 1314118/582044 797414/140887 particles...
# Read data for 1014814/1314118 1314118/582044 797414/141183 particles...
# Read data for 1014814/1314118 1314118/582044 797414/141234 particles...
# Read data for 1014814/1314118 1314118/582044 797414/141586 particles...
# Read data for 1014814/1314118 1314118/582044 797414/141700 particles...
# Read data for 1292042/1314118 1314118/758582 797414/182023 particles...
# Read data for 1292042/1314118 1314118/758582 797414/183096 particles...
# Read data for 1314118/1314118 1314118/797414 797414/195196 particles...

# %%
fig, ax = plt.subplots(1, 3, dpi=100, figsize=(15,5))

ax[0].scatter(zoom['pos3'][:,0], zoom['pos3'][:,1], marker='.', s=0.0005, color='C3')
ax[0].scatter(zoom['pos2'][:,0], zoom['pos2'][:,1], marker='.', s=0.0005, color='C2')
ax[0].scatter(zoom['pos1'][:,0], zoom['pos1'][:,1], marker='.', s=0.0005, color='C0')

ax[0].set_xlabel('$x[$Mpc$/h]$', fontsize=16)
ax[0].set_ylabel('$y[$Mpc$/h]$', fontsize=16)

ax[1].scatter(zoom['pos3'][:,0], zoom['pos3'][:,2], marker='.', s=0.0005, color='C3')
ax[1].scatter(zoom['pos2'][:,0], zoom['pos2'][:,2], marker='.', s=0.0005, color='C2')
ax[1].scatter(zoom['pos1'][:,0], zoom['pos1'][:,2], marker='.', s=0.0005, color='C0')

ax[1].set_xlabel('$x[$Mpc$/h]$', fontsize=16)
ax[1].set_ylabel('$z[$Mpc$/h]$', fontsize=16)

ax[2].scatter(zoom['pos3'][:,1], zoom['pos3'][:,2], marker='.', s=0.0005, color='C3')
ax[2].scatter(zoom['pos2'][:,1], zoom['pos2'][:,2], marker='.', s=0.0005, color='C2')
ax[2].scatter(zoom['pos1'][:,1], zoom['pos1'][:,2], marker='.', s=0.0005, color='C0')

ax[2].set_xlabel('$y[$Mpc$/h]$', fontsize=16)
ax[2].set_ylabel('$z[$Mpc$/h]$', fontsize=16)
# Out:
# Text(0, 0.5, '$z[$Mpc$/h]$')

# %% [markdown]
# ### 2, 4 and 10 halos

# %%
base = "/cosmos_storage/data_sharing/tmp_resims/1080-A/haloes_2/output/snapdir_000/"
zoom_2 = utils.read_zoom(base=base)

base = "/cosmos_storage/data_sharing/tmp_resims/1080-A/haloes_4/output/snapdir_000/"
zoom_4 = utils.read_zoom(base=base)

base = "/cosmos_storage/data_sharing/tmp_resims/1080-A/haloes_10/output/snapdir_000/"
zoom_10 = utils.read_zoom(base=base)
# Out:
# Read data for 0/269658 269658/0 213975/16 particles...
# Read data for 0/269658 269658/0 213975/1971 particles...
# Read data for 24407/269658 269658/32005 213975/12502 particles...
# Read data for 24407/269658 269658/32005 213975/12679 particles...
# Read data for 24407/269658 269658/32005 213975/13570 particles...
# Read data for 261710/269658 269658/196784 213975/51843 particles...
# Read data for 269658/269658 269658/213975 213975/59605 particles...
# Read data for 269658/269658 269658/213975 213975/59712 particles...
# Read data for 269658/269658 269658/213975 213975/60183 particles...
# Read data for 269658/269658 269658/213975 213975/60290 particles...
# Read data for 269658/269658 269658/213975 213975/60782 particles...
# Read data for 269658/269658 269658/213975 213975/61246 particles...
# Read data for 269658/269658 269658/213975 213975/61339 particles...
# Read data for 269658/269658 269658/213975 213975/61495 particles...
# Read data for 269658/269658 269658/213975 213975/61826 particles...
# Read data for 269658/269658 269658/213975 213975/61940 particles...
# Read data for 269658/269658 269658/213975 213975/62047 particles...
# Read data for 269658/269658 269658/213975 213975/62119 particles...
# Read data for 269658/269658 269658/213975 213975/62177 particles...
# Read data for 269658/269658 269658/213975 213975/62361 particles...
# Read data for 292975/691632 691632/283650 695024/91885 particles...
# Read data for 292975/691632 691632/283650 695024/92363 particles...
# Read data for 292975/691632 691632/289529 695024/98218 particles...
# Read data for 334543/691632 691632/346194 695024/116811 particles...
# Read data for 334543/691632 691632/350901 695024/121564 particles...
# Read data for 346588/691632 691632/374196 695024/131084 particles...
# Read data for 354225/691632 691632/392300 695024/139121 particles...
# Read data for 354225/691632 691632/392300 695024/139690 particles...
# Read data for 354225/691632 691632/392300 695024/140399 particles...
# Read data for 354225/691632 691632/392300 695024/141577 particles...
# Read data for 354225/691632 691632/392300 695024/142314 particles...
# Read data for 354225/691632 691632/392300 695024/142673 particles...
# Read data for 354225/691632 691632/392300 695024/143732 particles...
# Read data for 468638/691632 691632/506005 695024/174047 particles...
# Read data for 486671/691632 691632/540691 695024/189833 particles...
# Read data for 486671/691632 691632/540691 695024/189982 particles...
# Read data for 486671/691632 691632/540691 695024/190677 particles...
# Read data for 691450/691632 691632/690206 695024/223318 particles...
# Read data for 691450/691632 691632/690206 695024/223467 particles...
# Read data for 691450/691632 691632/690206 695024/224197 particles...
# Read data for 691450/691632 691632/690206 695024/224612 particles...
# Read data for 691632/691632 691632/695024 695024/228528 particles...

# %%
fig, ax = plt.subplots(3, 3, dpi=100, figsize=(15,15))

labels = ['$x[$Mpc$/h]$', '$y[$Mpc$/h]$', '$z[$Mpc$/h]$']

for i in range(3):
    ax[0,i].scatter(zoom_2['pos3'][:,i], zoom_2['pos3'][:,(i+1)%3], marker='.', s=0.0005, color='C3')
    ax[0,i].scatter(zoom_2['pos2'][:,i], zoom_2['pos2'][:,(i+1)%3], marker='.', s=0.0005, color='C2')
    ax[0,i].scatter(zoom_2['pos1'][:,i], zoom_2['pos1'][:,(i+1)%3], marker='.', s=0.0005, color='C0')

    ax[0,i].set_xlabel(labels[i], fontsize=16)
    ax[0,i].set_ylabel(labels[(i+1)%3], fontsize=16)

    ax[1,i].scatter(zoom_4['pos3'][:,i], zoom_4['pos3'][:,(i+1)%3], marker='.', s=0.0005, color='C3')
    ax[1,i].scatter(zoom_4['pos2'][:,i], zoom_4['pos2'][:,(i+1)%3], marker='.', s=0.0005, color='C2')
    ax[1,i].scatter(zoom_4['pos1'][:,i], zoom_4['pos1'][:,(i+1)%3], marker='.', s=0.0005, color='C0')

    ax[1,i].set_xlabel(labels[i], fontsize=16)
    ax[1,i].set_ylabel(labels[(i+1)%3], fontsize=16)

    ax[2,i].scatter(zoom_10['pos3'][:,i], zoom_10['pos3'][:,(i+1)%3], marker='.', s=0.0005, color='C3')
    ax[2,i].scatter(zoom_10['pos2'][:,i], zoom_10['pos2'][:,(i+1)%3], marker='.', s=0.0005, color='C2')
    ax[2,i].scatter(zoom_10['pos1'][:,i], zoom_10['pos1'][:,(i+1)%3], marker='.', s=0.0005, color='C0')

    ax[2,i].set_xlabel(labels[i], fontsize=16)
    ax[2,i].set_ylabel(labels[(i+1)%3], fontsize=16)
