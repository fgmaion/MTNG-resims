# %%
import numpy as np
import bacco
import matplotlib.pyplot as plt

# %%
import os
os.chdir("/cosmos_storage/home/fgmaion/MTNG-resims/src")
import utils

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
def pars(i, mstar):

    arr = np.vstack( ( mstar, np.ones(len(mstar)) * wind_en[i],\
                        np.ones(len(mstar)) * wind_vel[i],\
                        np.ones(len(mstar)) * rho_rec[i],\
                        np.ones(len(mstar)) * sf_ts[i],\
                        np.ones(len(mstar)) * ef_kin[i],\
                        np.ones(len(mstar)) * ef_high[i],\
                        np.ones(len(mstar)) * f_re[i])).T

    return arr

# %%
wind_en_or      = []
wind_vel_or     = []
rho_rec_or      = []
sf_ts_or        = []
ef_kin_or       = []
ef_high_or      = []
f_re_or         = []

for i in range(31):
    if i<30:
        filename = "/cosmos_storage/simulations/TNG_Family/MN5_resims/param_LH/param_MTNG-hydro_{:d}.txt".format(i)
    else:
        filename = "/cosmos_storage/simulations/TNG_Family/MN5_resims/param_LH/param_MTNG-hydro.txt"

    with open(filename, 'r') as f:
        for line in f.readlines():
            if len(line.split())!=0:
                if line.split()[0] == 'WindEnergyIn1e51erg':
                    wind_en_or.append(float(line.split()[1]))
                if line.split()[0] == 'VariableWindVelFactor':
                    wind_vel_or.append(float(line.split()[1]))
                if line.split()[0] == 'WindFreeTravelDensFac':
                    rho_rec_or.append(float(line.split()[1]))
                if line.split()[0] == 'MaxSfrTimescale':
                    sf_ts_or.append(float(line.split()[1]))
                if line.split()[0] == 'RadioFeedbackFactor':
                    ef_kin_or.append(float(line.split()[1]))
                if line.split()[0] == 'BlackHoleFeedbackFactor':
                    ef_high_or.append(float(line.split()[1]))
                if line.split()[0] == 'RadioFeedbackReiorientationFactor':
                    f_re_or.append(float(line.split()[1]))

rho_rec_or = np.log10(rho_rec_or)
ef_kin_or = np.log10(ef_kin_or)
        
wind_en   = (np.asarray(wind_en_or) - np.mean(wind_en_or)) / np.std(wind_en_or)
wind_vel  = (np.asarray(wind_vel_or) - np.mean(wind_vel_or)) / np.std(wind_vel_or)
rho_rec   = (np.asarray(rho_rec_or) - np.mean(rho_rec_or)) / np.std(rho_rec_or)
sf_ts     = (np.asarray(sf_ts_or) - np.mean(sf_ts_or)) / np.std(sf_ts_or)
ef_kin    = (np.asarray(ef_kin_or) - np.mean(ef_kin_or)) / np.std(ef_kin_or)
ef_high   = (np.asarray(ef_high_or) - np.mean(ef_high_or)) / np.std(ef_high_or)
f_re      = (np.asarray(f_re_or) - np.mean(f_re_or)) / np.std(f_re_or)

# %%
name_list = ['LH_{:d}'.format(i) for i in range(30)] + ['fiducial']

sigma8 = 0.8159 #CHECK ME
ns     = 0.9667 #CHECK ME
tau    = 0.0965 #CHECK ME

snap = 264
zoom = {}

for i in range(len(name_list)):
    if i<30:
        base = "/cosmos_storage/simulations/TNG_Family/MN5_resims/LH_{:d}/hydro_output/".format(i)
    else:
        base = "/cosmos_storage/simulations/TNG_Family/MN5_resims/fiducial/hydro_output/"
    zoom[name_list[i]] = bacco.Simulation(basedir=base, halo_file="groups_{:03d}/fof_subhalo_tab_{:03d}".format(snap,snap), sim_format='TNG500', fixedPk=True, use_orphans=False,\
                            tau=tau, ns=ns, sigma8=sigma8, dm_file="snapdir_{:03d}/snapshot_{:03d}".format(snap,snap), use_ids=True, numpart=4320)
# Out:
# 2026-04-22 00:47:09,079 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:09,079 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_0/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:09,081 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_0/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:09,566 bacco.sims : ...done in 0.0054 s
# 2026-04-22 00:47:09,566 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:09,567 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_1/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:09,568 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_1/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:09,987 bacco.sims : ...done in 0.00452 s
# 2026-04-22 00:47:09,987 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:09,988 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_2/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:09,991 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_2/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:10,000 bacco.sims : ...done in 0.00976 s
# 2026-04-22 00:47:10,001 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:10,002 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_3/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:10,005 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_3/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:10,413 bacco.sims : ...done in 0.0086 s
# 2026-04-22 00:47:10,414 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:10,416 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_4/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:10,419 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_4/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:10,423 bacco.sims : Creating snapshot array from /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_4/hydro_output/snapdir_264/snapshot_264 because: exists=True, newer=False
# 2026-04-22 00:47:10,425 bacco.sims : File exists but without write permission. We will use the existing snaplist.txt file.
# 2026-04-22 00:47:10,427 bacco.sims : ...done in 0.00932 s
# 2026-04-22 00:47:10,428 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:10,428 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_5/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:10,430 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_5/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:10,691 bacco.sims : ...done in 0.00463 s
# 2026-04-22 00:47:10,704 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:10,715 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_6/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:10,717 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_6/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:11,038 bacco.sims : ...done in 0.0158 s
# 2026-04-22 00:47:11,042 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:11,042 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_7/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:11,046 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_7/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:11,466 bacco.sims : ...done in 0.009 s
# 2026-04-22 00:47:11,466 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:11,467 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_8/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:11,468 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_8/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:11,473 bacco.sims : ...done in 0.00496 s
# 2026-04-22 00:47:11,474 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:11,474 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_9/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:11,475 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_9/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:11,745 bacco.sims : ...done in 0.00439 s
# 2026-04-22 00:47:11,746 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:11,746 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_10/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:11,748 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_10/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:11,997 bacco.sims : ...done in 0.00508 s
# 2026-04-22 00:47:12,001 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:12,001 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_11/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,003 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_11/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,007 bacco.sims : ...done in 0.00495 s
# 2026-04-22 00:47:12,008 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:12,008 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_12/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,009 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_12/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,014 bacco.sims : ...done in 0.00445 s
# 2026-04-22 00:47:12,015 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:12,015 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_13/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,016 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_13/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,020 bacco.sims : ...done in 0.00421 s
# 2026-04-22 00:47:12,021 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:12,021 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_14/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,022 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_14/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,027 bacco.sims : ...done in 0.00421 s
# 2026-04-22 00:47:12,027 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:12,028 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_15/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,029 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_15/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,463 bacco.sims : ...done in 0.00415 s
# 2026-04-22 00:47:12,464 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:12,465 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_16/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,466 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_16/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,716 bacco.sims : ...done in 0.005 s
# 2026-04-22 00:47:12,717 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:12,717 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_17/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,724 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_17/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,733 bacco.sims : ...done in 0.0102 s
# 2026-04-22 00:47:12,734 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:12,734 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_18/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,740 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_18/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,744 bacco.sims : ...done in 0.00883 s
# 2026-04-22 00:47:12,745 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:12,745 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_19/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,747 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_19/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,751 bacco.sims : ...done in 0.00443 s
# 2026-04-22 00:47:12,751 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:12,752 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_20/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,753 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_20/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,756 bacco.sims : ...done in 0.00361 s
# 2026-04-22 00:47:12,757 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:12,757 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_21/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,758 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_21/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,762 bacco.sims : ...done in 0.00388 s
# 2026-04-22 00:47:12,763 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:12,763 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_22/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,764 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_22/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,768 bacco.sims : ...done in 0.00356 s
# 2026-04-22 00:47:12,768 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:12,768 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_23/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,769 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_23/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,773 bacco.sims : ...done in 0.00358 s
# 2026-04-22 00:47:12,774 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:12,774 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_24/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,775 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_24/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,779 bacco.sims : ...done in 0.0034 s
# 2026-04-22 00:47:12,779 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:12,779 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_25/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:12,780 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_25/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:13,251 bacco.sims : ...done in 0.00363 s
# 2026-04-22 00:47:13,252 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:13,252 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_26/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:13,254 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_26/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:13,684 bacco.sims : ...done in 0.0045 s
# 2026-04-22 00:47:13,685 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:13,687 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_27/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:13,689 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_27/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:14,104 bacco.sims : ...done in 0.00852 s
# 2026-04-22 00:47:14,104 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:14,107 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_28/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:14,108 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_28/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:14,527 bacco.sims : ...done in 0.00871 s
# 2026-04-22 00:47:14,528 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:14,531 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_29/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:14,533 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/LH_29/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:14,956 bacco.sims : ...done in 0.011 s
# 2026-04-22 00:47:14,957 bacco.sims : Initialising simulation Default
# 2026-04-22 00:47:14,957 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MN5_resims/fiducial/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:14,963 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MN5_resims/fiducial/hydro_output/snapdir_264/snapshot_264
# 2026-04-22 00:47:15,422 bacco.sims : ...done in 0.00964 s

# %%
# Load the Halo Selection
with open("/cosmos_storage/simulations/TNG_Family/MN5_resims/resims_info/hydro_halo_sel_1pmbin.txt") as f:
    final_sel = []

    for line in f.readlines():
        final_sel.append(int(line.split()[0]))

final_sel = np.array(final_sel)

# Perform the cross-match with MTNG halos
xmatch = {}

for i in range(len(name_list)):
    xmatch[name_list[i]] = utils.cross_match(zoom[name_list[i]], snap=264, name=name_list[i])

# Load MTNG and get the fraction of halos to do the upweighting
mtng = bacco.utils.load_MTNG(adr="/cosmos_storage/simulations/TNG_Family/MTNG/", snap=264)

m200b = np.log10(1e10 * mtng.fof['halo_m200b'])

mbins = np.concatenate(
    (np.arange(11, 11.5, 0.0025),
    np.arange(11.5, 12.5, 0.005),
    np.arange(12.5, 13.5, 0.025),
    np.arange(13.5, 15.01, 0.125))
)

h_frac = np.zeros(len(final_sel))
for m in range(len(mbins)-1):
    h_frac[m] = np.where(( m200b[final_sel]>=mbins[m]) & ( m200b[final_sel]<mbins[m+1]))[0].shape[0] / \
             np.where(( m200b>=mbins[m]) & ( m200b<mbins[m+1]))[0].shape[0]

zoom_split = {}
zoom_sel = {}
for i in range(len(name_list)):
    zoom_split[name_list[i]] = utils.split_halos(zoom[name_list[i]])

    zoom_sel[name_list[i]] = {}

    zoom_sel[name_list[i]]['sel'] = xmatch[name_list[i]]['ind'][:,np.newaxis,np.newaxis]
    zoom_sel[name_list[i]]['h_frac'] = h_frac[np.newaxis, :]
# Out:
# 2026-03-16 20:03:23,301 bacco.sims : Initialising simulation Default
# 2026-03-16 20:03:23,301 bacco.sims : try /cosmos_storage/simulations/TNG_Family/MTNG/groups_264/fof_subhalo_tab_264
# 2026-03-16 20:03:23,303 bacco.sims : Loading /cosmos_storage/simulations/TNG_Family/MTNG/groups_264/fof_subhalo_tab_264
# 2026-03-16 20:03:23,331 bacco.sims : ...done in 0.00518 s
# 2026-03-16 20:03:23,337 bacco.sims : Reading 98233510 items for Group_M_Mean200
# /tmp/ipykernel_386577/87356854.py:19: RuntimeWarning: divide by zero encountered in log10
#   m200b = np.log10(1e10 * mtng.fof['halo_m200b'])

# %%
bh_mf = {}

for i in range(len(name_list)):
    bh_mf[name_list[i]] = zoom_split[name_list[i]].bh_mf(sel_mask=zoom_sel[name_list[i]], nbins=20)
# Out:
# 2026-03-16 20:06:26,272 bacco.sims : Reading 142791 items for halo_firstsub
# 2026-03-16 20:06:26,869 bacco.sims : Reading 142791 items for GroupNsubs
# 2026-03-16 20:06:26,891 bacco.sims : Reading 76572 items for SubhaloBHMass
# 2026-03-16 20:06:27,440 bacco.sims : Reading 143520 items for halo_firstsub
# 2026-03-16 20:06:28,086 bacco.sims : Reading 143520 items for GroupNsubs
# 2026-03-16 20:06:28,104 bacco.sims : Reading 74995 items for SubhaloBHMass
# 2026-03-16 20:06:28,663 bacco.sims : Reading 146601 items for halo_firstsub
# 2026-03-16 20:06:29,302 bacco.sims : Reading 146601 items for GroupNsubs
# 2026-03-16 20:06:29,331 bacco.sims : Reading 76208 items for SubhaloBHMass
# 2026-03-16 20:06:29,732 bacco.sims : Reading 141432 items for halo_firstsub
# 2026-03-16 20:06:30,367 bacco.sims : Reading 141432 items for GroupNsubs
# 2026-03-16 20:06:30,397 bacco.sims : Reading 75118 items for SubhaloBHMass
# 2026-03-16 20:06:30,975 bacco.sims : Reading 145271 items for halo_firstsub
# 2026-03-16 20:06:31,636 bacco.sims : Reading 145271 items for GroupNsubs
# 2026-03-16 20:06:31,661 bacco.sims : Reading 76079 items for SubhaloBHMass
# /cosmos_storage/home/fgmaion/MTNG-resims/src/utils.py:303: RuntimeWarning: invalid value encountered in divide
#   mbh_mean = mbh_mean / counts
# 2026-03-16 20:06:32,186 bacco.sims : Reading 145320 items for halo_firstsub
# 2026-03-16 20:06:32,804 bacco.sims : Reading 145320 items for GroupNsubs
# 2026-03-16 20:06:32,834 bacco.sims : Reading 75930 items for SubhaloBHMass
# 2026-03-16 20:06:33,266 bacco.sims : Reading 146135 items for halo_firstsub
# 2026-03-16 20:06:33,903 bacco.sims : Reading 146135 items for GroupNsubs
# 2026-03-16 20:06:33,932 bacco.sims : Reading 76106 items for SubhaloBHMass
# 2026-03-16 20:06:34,338 bacco.sims : Reading 139876 items for halo_firstsub
# 2026-03-16 20:06:35,055 bacco.sims : Reading 139876 items for GroupNsubs
# 2026-03-16 20:06:35,077 bacco.sims : Reading 74186 items for SubhaloBHMass
# 2026-03-16 20:06:35,675 bacco.sims : Reading 142352 items for halo_firstsub
# 2026-03-16 20:06:36,389 bacco.sims : Reading 142352 items for GroupNsubs
# 2026-03-16 20:06:36,425 bacco.sims : Reading 74620 items for SubhaloBHMass
# 2026-03-16 20:06:36,773 bacco.sims : Reading 144105 items for halo_firstsub
# 2026-03-16 20:06:37,309 bacco.sims : Reading 144105 items for GroupNsubs
# 2026-03-16 20:06:37,324 bacco.sims : Reading 75728 items for SubhaloBHMass
# 2026-03-16 20:06:37,791 bacco.sims : Reading 135036 items for halo_firstsub
# 2026-03-16 20:06:38,523 bacco.sims : Reading 135036 items for GroupNsubs
# 2026-03-16 20:06:38,554 bacco.sims : Reading 73687 items for SubhaloBHMass
# 2026-03-16 20:06:39,224 bacco.sims : Reading 139921 items for halo_firstsub
# 2026-03-16 20:06:39,963 bacco.sims : Reading 139921 items for GroupNsubs
# 2026-03-16 20:06:39,995 bacco.sims : Reading 73880 items for SubhaloBHMass
# 2026-03-16 20:06:41,244 bacco.sims : Reading 141667 items for halo_firstsub
# 2026-03-16 20:06:41,969 bacco.sims : Reading 141667 items for GroupNsubs
# 2026-03-16 20:06:41,988 bacco.sims : Reading 75240 items for SubhaloBHMass
# 2026-03-16 20:06:42,529 bacco.sims : Reading 142176 items for halo_firstsub
# 2026-03-16 20:06:43,127 bacco.sims : Reading 142176 items for GroupNsubs
# 2026-03-16 20:06:43,142 bacco.sims : Reading 75407 items for SubhaloBHMass
# 2026-03-16 20:06:43,510 bacco.sims : Reading 144687 items for halo_firstsub
# 2026-03-16 20:06:44,273 bacco.sims : Reading 144687 items for GroupNsubs
# 2026-03-16 20:06:44,299 bacco.sims : Reading 75698 items for SubhaloBHMass
# 2026-03-16 20:06:44,776 bacco.sims : Reading 143454 items for halo_firstsub
# 2026-03-16 20:06:45,563 bacco.sims : Reading 143454 items for GroupNsubs
# 2026-03-16 20:06:45,585 bacco.sims : Reading 75302 items for SubhaloBHMass
# 2026-03-16 20:06:46,081 bacco.sims : Reading 139438 items for halo_firstsub
# 2026-03-16 20:06:46,669 bacco.sims : Reading 139438 items for GroupNsubs
# 2026-03-16 20:06:46,693 bacco.sims : Reading 74596 items for SubhaloBHMass
# 2026-03-16 20:06:47,197 bacco.sims : Reading 141389 items for halo_firstsub
# 2026-03-16 20:06:47,807 bacco.sims : Reading 141389 items for GroupNsubs
# 2026-03-16 20:06:47,823 bacco.sims : Reading 74844 items for SubhaloBHMass
# 2026-03-16 20:06:48,149 bacco.sims : Reading 146650 items for halo_firstsub
# 2026-03-16 20:06:48,719 bacco.sims : Reading 146650 items for GroupNsubs
# 2026-03-16 20:06:48,751 bacco.sims : Reading 77144 items for SubhaloBHMass
# 2026-03-16 20:06:49,141 bacco.sims : Reading 131290 items for halo_firstsub
# 2026-03-16 20:06:49,665 bacco.sims : Reading 131290 items for GroupNsubs
# 2026-03-16 20:06:49,695 bacco.sims : Reading 72150 items for SubhaloBHMass
# 2026-03-16 20:06:50,092 bacco.sims : Reading 143189 items for halo_firstsub
# 2026-03-16 20:06:50,683 bacco.sims : Reading 143189 items for GroupNsubs
# 2026-03-16 20:06:50,710 bacco.sims : Reading 77662 items for SubhaloBHMass
# 2026-03-16 20:06:51,096 bacco.sims : Reading 135227 items for halo_firstsub
# 2026-03-16 20:06:51,635 bacco.sims : Reading 135227 items for GroupNsubs
# 2026-03-16 20:06:51,657 bacco.sims : Reading 73253 items for SubhaloBHMass
# 2026-03-16 20:06:52,142 bacco.sims : Reading 138822 items for halo_firstsub
# 2026-03-16 20:06:52,666 bacco.sims : Reading 138822 items for GroupNsubs
# 2026-03-16 20:06:52,699 bacco.sims : Reading 72894 items for SubhaloBHMass
# 2026-03-16 20:06:53,103 bacco.sims : Reading 142973 items for halo_firstsub
# 2026-03-16 20:06:53,637 bacco.sims : Reading 142973 items for GroupNsubs
# 2026-03-16 20:06:53,667 bacco.sims : Reading 75305 items for SubhaloBHMass
# 2026-03-16 20:06:54,044 bacco.sims : Reading 134298 items for halo_firstsub
# 2026-03-16 20:06:54,536 bacco.sims : Reading 134298 items for GroupNsubs
# 2026-03-16 20:06:54,565 bacco.sims : Reading 75027 items for SubhaloBHMass
# 2026-03-16 20:06:54,958 bacco.sims : Reading 146596 items for halo_firstsub
# 2026-03-16 20:06:55,471 bacco.sims : Reading 146596 items for GroupNsubs
# 2026-03-16 20:06:55,505 bacco.sims : Reading 76658 items for SubhaloBHMass
# 2026-03-16 20:06:55,856 bacco.sims : Reading 144335 items for halo_firstsub
# 2026-03-16 20:06:56,355 bacco.sims : Reading 144335 items for GroupNsubs
# 2026-03-16 20:06:56,382 bacco.sims : Reading 76316 items for SubhaloBHMass
# 2026-03-16 20:06:56,770 bacco.sims : Reading 141206 items for halo_firstsub
# 2026-03-16 20:06:57,223 bacco.sims : Reading 141206 items for GroupNsubs
# 2026-03-16 20:06:57,240 bacco.sims : Reading 74475 items for SubhaloBHMass
# 2026-03-16 20:06:57,774 bacco.sims : Reading 142714 items for halo_firstsub
# 2026-03-16 20:06:58,297 bacco.sims : Reading 142714 items for GroupNsubs
# 2026-03-16 20:06:58,314 bacco.sims : Reading 75564 items for SubhaloBHMass
# 2026-03-16 20:06:58,709 bacco.sims : Reading 139249 items for halo_firstsub
# 2026-03-16 20:06:59,208 bacco.sims : Reading 139249 items for GroupNsubs
# 2026-03-16 20:06:59,241 bacco.sims : Reading 73370 items for SubhaloBHMass
# 2026-03-16 20:06:59,638 bacco.sims : Reading 139956 items for halo_firstsub
# 2026-03-16 20:06:59,966 bacco.sims : Reading 139956 items for GroupNsubs
# 2026-03-16 20:06:59,993 bacco.sims : Reading 74777 items for SubhaloBHMass

# %%
mtng_bhmf = utils.get_mtng_bhmf(mtng, nbins=20)
# Out:
# 2026-03-16 20:07:00,773 bacco.sims : Reading 90246895 items for SubhaloBHMass

# %%
# Load BHMF
Nbins_bhmf = 10

zoom_bhmf = {}
for i in range(len(name_list)):
    zoom_bhmf[name_list[i]] = np.load("/cosmos_storage/home/fgmaion/MTNG-resims/results/bhmf/bhmf_{}_Nbins{:d}.npy".format(name_list[i], Nbins_bhmf), allow_pickle=True)[0]

# %%
fig, ax = plt.subplots(dpi=200, figsize=(5.5,5))

ax.set_xscale('log')
ax.set_yscale('log')

ax.set_ylabel(r"$\Phi(M_{\rm BH})$ [Mpc$^{-3}$ dex$^{-1}$]")
ax.set_xlabel(r"$M_{\rm BH}$ [$M_\odot$]")

for i in range(len(name_list)-1):
    ax.plot(zoom_bhmf[name_list[i]]['mbh'], zoom_bhmf[name_list[i]]['bhmf'], color='gray', alpha=0.5, lw=1)

ax.plot(zoom_bhmf['fiducial']['mbh'], zoom_bhmf['fiducial']['bhmf'], label='Fiducial', color='C3', lw=2)
# ax.plot(mtng_bhmf['mbh'], mtng_bhmf['bhmf'], label='MTNG', color='k', lw=2)

ax.legend()

# %%
import sys
sys.path.append("/cosmos_storage/home/fgmaion/MTNG-resims/scripts")
from GP_models import SMF_Model, fgas_Model
import torch
import gpytorch

# %% [markdown]
# ### Load the data

# %%
Nbins_mbh_mstar = 10

zoom_mbh = {}
for i in range(len(name_list)):
    zoom_mbh[name_list[i]] = np.load("/cosmos_storage/home/fgmaion/MTNG-resims/results/mbh_mstar/mbh_mstar_{}_Nbins{:d}.npy".format(name_list[i], Nbins_mbh_mstar), allow_pickle=True)[0]

# Filter NaNs
for i in range(len(name_list)):
    mask = ~np.isnan(zoom_mbh[name_list[i]]['mbh_mean']) & ~np.isnan(zoom_mbh[name_list[i]]['mstar_mean'])
    
    zoom_mbh[name_list[i]]['mbh_mean'] = zoom_mbh[name_list[i]]['mbh_mean'][mask]
    zoom_mbh[name_list[i]]['mstar_mean'] = zoom_mbh[name_list[i]]['mstar_mean'][mask]

# %%
fig, ax = plt.subplots(dpi=200, figsize=(5.5,5))

ax.set_xscale('log')
ax.set_yscale('log')
ax.plot(zoom_mbh['fiducial']['mstar_mean'], zoom_mbh['fiducial']['mbh_mean'], label='Fiducial', color='C3', lw=2)

# %%
model_mbh_mstar = torch.load("/cosmos_storage/home/fgmaion/MTNG-resims/gp_train_results/full_model_mbh_mstar.pth")
likelihood_mbh_mstar = torch.load("/cosmos_storage/home/fgmaion/MTNG-resims/gp_train_results/full_likelihood_mbh_mstar.pth")

model_mbh_mstar.eval()
likelihood_mbh_mstar.eval()
# Out:
# /tmp/ipykernel_71711/1222056788.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_mbh_mstar = torch.load("/cosmos_storage/home/fgmaion/MTNG-resims/gp_train_results/full_model_mbh_mstar.pth")
# /tmp/ipykernel_71711/1222056788.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   likelihood_mbh_mstar = torch.load("/cosmos_storage/home/fgmaion/MTNG-resims/gp_train_results/full_likelihood_mbh_mstar.pth")
# GaussianLikelihood(
#   (noise_covar): HomoskedasticNoise(
#     (raw_noise_constraint): GreaterThan(1.000E-02)
#   )
# )

# %%
# Define the training set
train_sel = np.arange(31)

# %%
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    # Initialize plot
    f, ax = plt.subplots(2, 3, figsize=(15, 10), dpi=100)
    plt.subplots_adjust(wspace=0.15, hspace=0.3)

    for i in range(2):
        for j in range(3):
            test_x = torch.asarray(pars(train_sel[3*i+j], np.log10(zoom_mbh[name_list[train_sel[3*i+j]]]['mstar_mean'])), dtype=torch.float)
            observed_pred = likelihood_mbh_mstar(model_mbh_mstar(torch.asarray(test_x, dtype=torch.float)))
        

            ax[i,j].set_title('Simulation {:s}'.format(name_list[train_sel[3*i+j]]), fontsize=16)

            if j==0:
                ax[i,j].set_ylabel('$M_{\mathrm{BH}}$', fontsize=16)
            
            ax[i,j].set_xlabel('$M_*$', fontsize=16)

            # Get upper and lower confidence bounds
            lower, upper = observed_pred.confidence_region()

            # Shade between the lower and upper confidence bounds
            ax[i,j].fill_between(test_x[:,0].numpy(), observed_pred.mean.numpy()-observed_pred.stddev.numpy(), observed_pred.mean.numpy()+observed_pred.stddev.numpy(), color='C0', alpha=0.4, edgecolor=None)
            ax[i,j].plot(test_x[:,0], observed_pred.mean.numpy(), 'C0', lw=2, label="GP Prediction", alpha=0.9)

            # Plot test data as blue squares
            ax[i,j].plot(np.log10(zoom_mbh[name_list[train_sel[3*i+j]]]['mstar_mean']), np.log10(zoom_mbh[name_list[train_sel[3*i+j]]]['mbh_mean']), 's', color="C0", label="Test Data")

ax[0,0].legend(loc='lower left', fontsize=12)
