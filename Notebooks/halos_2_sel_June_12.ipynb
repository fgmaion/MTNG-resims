# %%
import numpy as np
import bacco
import matplotlib.pyplot as plt

# %%
import os
os.chdir("/lscratch/fgmaion/MTNG-resims/src")
import utils

# %%
basedir_2 = "/cosmos_storage/data_sharing/tmp_resims/1080-A/haloes_2/output/"
basedir_4 = "/cosmos_storage/data_sharing/tmp_resims/1080-A/haloes_4/output/"

resolution_level=1

sigma8 = 0.8159 #CHECK ME
ns     = 0.9667 #CHECK ME
tau    = 0.0965 #CHECK ME
numpart = int(1080**3*2**(3-3*resolution_level))

zoom_2 = bacco.Simulation(basedir=basedir_2, dm_file="snapdir_010/snapshot_010", sim_format='TNG500', fixedPk=True, sigma8=sigma8,\
    tau=tau, ns=ns, numpart=numpart)
zoom_4 = bacco.Simulation(basedir=basedir_4, dm_file="snapdir_010/snapshot_010", sim_format='TNG500', fixedPk=True, sigma8=sigma8,\
    tau=tau, ns=ns, numpart=numpart)
#zoom_10 = bacco.Simulation(basedir=basedir, halo_file="groups_010/fof_subhalo_tab_010", sim_format='gadget4_hdf5', fixedPk=True, sigma8=sigma8,\
#    tau=tau, ns=ns, numpart=numpart)
# Out:
# 2024-06-12 19:49:31,200 bacco.sims : Initialising simulation Default
# 2024-06-12 19:49:31,202 bacco.sims : try /cosmos_storage/data_sharing/tmp_resims/1080-A/haloes_2/output/snapdir_010/snapshot_010
# 2024-06-12 19:49:31,206 bacco.sims : Loading /cosmos_storage/data_sharing/tmp_resims/1080-A/haloes_2/output/snapdir_010/snapshot_010
# 2024-06-12 19:49:31,213 bacco.sims : ...done in 0.013 s
# 2024-06-12 19:49:31,214 bacco.sims : Initialising simulation Default
# 2024-06-12 19:49:31,215 bacco.sims : try /cosmos_storage/data_sharing/tmp_resims/1080-A/haloes_4/output/snapdir_010/snapshot_010
# 2024-06-12 19:49:31,217 bacco.sims : Loading /cosmos_storage/data_sharing/tmp_resims/1080-A/haloes_4/output/snapdir_010/snapshot_010
# 2024-06-12 19:49:31,220 bacco.sims : ...done in 0.00607 s

# %%
zoom_2.dm.keys()
# Out:
# 2024-06-12 19:49:35,683 bacco.sims : Read data for 0 8589/1259712000 particles...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 zoom_2.dm.keys()
#
# File /lscratch/fgmaion/baccogit/bacco/utils.py:257, in cached_property.__get__(self, obj, type)
#     255 value = obj.__dict__.get(self.__name__, _missing)
#     256 if value is _missing:
# --> 257     value = self.func(obj)
#     258     obj.__dict__[self.__name__] = value
#     259 return value
#
# File /lscratch/fgmaion/baccogit/bacco/simulation.py:3393, in dm(self)
#    3391
#    3392         if self.sim_format in ['gadget_hdf5', 'gadget4_hdf5', "TNG_onlyDM", "TNG", 'TNG500']:
# -> 3393             pos, vel, ids = self._load_dark_matter_gadget_hdf5(
#    3394                 do_compression=self.do_compression, dask=self.dask)
# ...
