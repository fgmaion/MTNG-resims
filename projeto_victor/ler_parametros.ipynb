# %%
import h5py
import numpy as np

# %%
import h5py
import numpy as np

i = 0
snap = 264

with h5py.File("/cosmos_storage/simulations/TNG_Family/MN5_resims/LH_{:d}/hydro_output/groups_{:03d}/fof_subhalo_tab_{:03d}.0.hdf5".format(i, snap, snap)) as f:
    # print(f.keys())
    # for i in range(len(f['Parameters'].attrs.keys())):
    #     print(list(f['Parameters'].attrs.keys())[i])

    print(f['Parameters'].attrs['WindEnergyIn1e51erg'])
    print(f['Parameters'].attrs['VariableWindVelFactor'])
    print(f['Parameters'].attrs['WindFreeTravelDensFac'])
    print(f['Parameters'].attrs['MaxSfrTimescale'])
    print(f['Parameters'].attrs['RadioFeedbackFactor'])
    print(f['Parameters'].attrs['BlackHoleFeedbackFactor'])
    print(f['Parameters'].attrs['RadioFeedbackReiorientationFactor'])

# %%
xm = np.load("/cosmos_storage/home/fgmaion/MTNG-resims/cross-match/xmatch_LH_0.npy", allow_pickle=True).item()
