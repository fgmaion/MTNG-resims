# %%
import numpy as np
import h5py

# %%
dir_name = "/scratch/cosmosims/TNG_Family/MTNG/"

# %%
with h5py.File(dir_name + "groups_252/fof_subhalo_tab_252.114.hdf5", 'r') as f:
    print(f.keys())
    N_group_props = len( f['Group'].keys() )
    print( f['Group'].keys() )
    N_sub_props = 3 * len( f['Subhalo'].keys() )
    print( f['Subhalo'].keys() )

    print( f['Group']['GroupMass'][...]/1e2)
    print( f['Group']['Group_M_Crit200'][...]/1e2)
    print( f['Group']['GroupNsubs'][...])
# Out:
# <KeysViewHDF5 ['Config', 'Group', 'Header', 'IDs', 'Parameters', 'Subhalo']>
# <KeysViewHDF5 ['GroupBHMass', 'GroupBHMdot', 'GroupFirstSub', 'GroupGasMetallicity', 'GroupLen', 'GroupLenPrevMostBnd', 'GroupLenType', 'GroupMass', 'GroupMassType', 'GroupNsubs', 'GroupOffsetType', 'GroupPos', 'GroupSFR', 'GroupStarMetallicity', 'GroupVel', 'GroupWindMass', 'Group_M_Crit200', 'Group_M_Crit500', 'Group_M_Mean200', 'Group_M_TopHat200', 'Group_R_Crit200', 'Group_R_Crit500', 'Group_R_Mean200', 'Group_R_TopHat200']>
# <KeysViewHDF5 ['SubhaloBHMass', 'SubhaloBHMdot', 'SubhaloCM', 'SubhaloGasMassSFR', 'SubhaloGasMetallicity', 'SubhaloGasMetallicityHalfRad', 'SubhaloGasMetallicityMaxRad', 'SubhaloGasMetallicitySfr', 'SubhaloGasMetallicityWeighted', 'SubhaloGroupNr', 'SubhaloHalfmassRad', 'SubhaloHalfmassRadType', 'SubhaloIDMostbound', 'SubhaloIntertiaTensorStars', 'SubhaloKineticEnergyStars', 'SubhaloLen', 'SubhaloLenPrevMostBnd', 'SubhaloLenType', 'SubhaloMass', 'SubhaloMassInHalfRad', 'SubhaloMassInHalfRadType', 'SubhaloMassInMaxRad', 'SubhaloMassInMaxRadType', 'SubhaloMassInRad', 'SubhaloMassInRadType', 'SubhaloMassType', 'SubhaloOffsetType', 'SubhaloParentRank', 'SubhaloPos', 'SubhaloRankInGr', 'SubhaloRotationalEnergyStars', 'SubhaloSFR', 'SubhaloSfrInHalfRad', 'SubhaloSfrInMaxRad', 'SubhaloSfrInRad', 'SubhaloSpin', 'SubhaloSpinType', 'SubhaloStarMetallicity', 'SubhaloStarMetallicityHalfRad', 'SubhaloStarMetallicityMaxRad', 'SubhaloStellarPhotometrics', 'SubhaloStellarPhotometricsMassInRad', 'SubhaloStellarPhotometricsRad', 'SubhaloTidalTensor', 'SubhaloVel', 'SubhaloVelDisp', 'SubhaloVmax', 'SubhaloVmaxRad', 'SubhaloWindMass']>
# [2.2458582 2.611772  2.237206  ... 1.1836443 1.31542   1.1823372]
# [1.4064918  2.457842   1.277546   ... 0.80865717 1.1943115  0.44740564]
# [14  7 15 ...  8  3 13]

# %% [markdown]
# ### Each group of $10^{12}M_{\odot}$ has around 20 subhalos

# %%
with h5py.File(dir_name + "groups_252/fof_subhalo_tab_252.100.hdf5", 'r') as f:
    print(f.keys())
    print( f['Group'].keys() )
    print( f['Subhalo'].keys() )

    print( f['Group']['GroupMass'][...]/1e3)
    print( f['Group']['Group_M_Crit200'][...]/1e3)
    print( f['Group']['GroupNsubs'][...])
# [5.565514  5.2223845 6.1650596 4.895604  4.668129  5.343279  5.8457265
#  5.4985065 4.675833  4.9567394 3.031739  5.3947034 4.8664646 5.9027853
#  5.4669394 5.555194  5.9758964 5.2457447 4.8939366 4.6678605 5.4023485
#  5.1308517 4.882272  5.613348  4.048578  5.7280803 5.227672  5.363768
#  3.608202  5.369572  5.8858995 3.0275342 3.7119968 2.0401015 5.0649486
#  5.2826595 5.370436  4.7701073 4.562517  5.1300955 5.1550136 4.4901576
#  1.5493772 4.4942193 3.0380442 5.3827434 4.9437695 3.4164727 5.74519
#  4.0975432 5.070376  3.7425954 5.690181  3.312928  4.6742325 5.665793
#  5.3714476 5.2874823 4.9775515 3.994753  2.0090406 2.7339613 5.3014636
#  2.6428585 5.804406  4.589407  5.718972  4.3967566 4.119699  4.217273
#  5.0367756 5.603526  3.8263338 5.5115004 5.5302234 4.366436  3.9583046
#  2.5964193 5.2513757 4.0571795 4.898295  3.6849616 5.644598  4.4401255
#  5.586534  4.3726377 4.828631  5.409219  5.2605    4.5817733 5.3823743
#  5.6224885 5.2945585 4.0087185 5.7513204 5.188207 ]
# [175 245 262 236 233 264 244 210 232 214 250 196 229 191 199 185 151 194
#  226 262 221 176 242 266 231 186 221 159 228 241 195 252 199 280 241 219
#  187 223 274 294 235 223 285 269 258 261 264 197 167 235 271 193 228 231
#  208 236 227 217 211 243 252 234 185 226 177 212 157 273 268 250 233 146
#  325 243 216 235 233 292 198 246 214 190 159 258 217 260 257 174 229 247
#  236 149 215 233 156 228]

# %% [markdown]
# ### Each group of $10^{13}M_{\odot}$ has around 200 subhalos

# %%
with h5py.File(dir_name + "groups_252/fof_subhalo_tab_252.10.hdf5", 'r') as f:
    print(f.keys())
    print( f['Group'].keys() )
    print( f['Subhalo'].keys() )

    print( f['Group']['GroupMass'][...]/1e4)
    print( f['Group']['Group_M_Crit200'][...]/1e4)
    print( f['Group']['GroupNsubs'][...])
# Out:
# <KeysViewHDF5 ['Config', 'Group', 'Header', 'IDs', 'Parameters', 'Subhalo']>
# <KeysViewHDF5 ['GroupBHMass', 'GroupBHMdot', 'GroupFirstSub', 'GroupGasMetallicity', 'GroupLen', 'GroupLenPrevMostBnd', 'GroupLenType', 'GroupMass', 'GroupMassType', 'GroupNsubs', 'GroupOffsetType', 'GroupPos', 'GroupSFR', 'GroupStarMetallicity', 'GroupVel', 'GroupWindMass', 'Group_M_Crit200', 'Group_M_Crit500', 'Group_M_Mean200', 'Group_M_TopHat200', 'Group_R_Crit200', 'Group_R_Crit500', 'Group_R_Mean200', 'Group_R_TopHat200']>
# <KeysViewHDF5 ['SubhaloBHMass', 'SubhaloBHMdot', 'SubhaloCM', 'SubhaloGasMassSFR', 'SubhaloGasMetallicity', 'SubhaloGasMetallicityHalfRad', 'SubhaloGasMetallicityMaxRad', 'SubhaloGasMetallicitySfr', 'SubhaloGasMetallicityWeighted', 'SubhaloGroupNr', 'SubhaloHalfmassRad', 'SubhaloHalfmassRadType', 'SubhaloIDMostbound', 'SubhaloIntertiaTensorStars', 'SubhaloKineticEnergyStars', 'SubhaloLen', 'SubhaloLenPrevMostBnd', 'SubhaloLenType', 'SubhaloMass', 'SubhaloMassInHalfRad', 'SubhaloMassInHalfRadType', 'SubhaloMassInMaxRad', 'SubhaloMassInMaxRadType', 'SubhaloMassInRad', 'SubhaloMassInRadType', 'SubhaloMassType', 'SubhaloOffsetType', 'SubhaloParentRank', 'SubhaloPos', 'SubhaloRankInGr', 'SubhaloRotationalEnergyStars', 'SubhaloSFR', 'SubhaloSfrInHalfRad', 'SubhaloSfrInMaxRad', 'SubhaloSfrInRad', 'SubhaloSpin', 'SubhaloSpinType', 'SubhaloStarMetallicity', 'SubhaloStarMetallicityHalfRad', 'SubhaloStarMetallicityMaxRad', 'SubhaloStellarPhotometrics', 'SubhaloStellarPhotometricsMassInRad', 'SubhaloStellarPhotometricsRad', 'SubhaloTidalTensor', 'SubhaloVel', 'SubhaloVelDisp', 'SubhaloVmax', 'SubhaloVmaxRad', 'SubhaloWindMass']>
# [5.3213468 5.3397408 5.3361406 5.3139467 5.2962875 5.2472515 5.2277436
#  5.266739  5.2035465 5.183492  5.134273  5.1516857 5.108358  5.1856885
#  5.030427  5.0843587 5.032523  4.9420905 4.929667 ]
# [3.7509944 4.547698  2.3502777 4.3861103 4.525558  3.9322453 3.989253
#  4.5229397 3.8807766 2.0739503 3.816125  4.5729914 4.6107345 3.8713558
#  2.7391226 4.072798  3.0154912 3.519293  4.027777 ]
# [1687 1357 1709 1558 1769 1420 1998 1456 1624 1576 1492 1469 1530 1706
#  1607 1508 1516 1712 1526]

# %% [markdown]
# ### Each group of around $10^{14}M_{\odot}$ has 1500 subhalos

# %%
N_h = 40/3

mem_12 = N_h * 20 * N_sub_props * 4 + N_h * N_group_props * 4
mem_13 = N_h * 200 * N_sub_props * 4 + N_h * N_group_props * 4
mem_14 = N_h * 2000 * N_sub_props * 4 + N_h * N_group_props * 4

# number of halos * number of subahlos * number of properties * number of bytes

# %% [markdown]
# ### This is a giant halo, almost $10^{15}$ in halo mass

# %%
with h5py.File("/cosmos_storage/MTNG/treedata/trees.{:d}.hdf5".format(20), 'r') as f:
    print( f.keys() )
    print( f['TreeTable'].keys() )
    nsubs = f['TreeTable']['Length'][...]
    print( f['TreeHalos'] )
    print( f['TreeHalos'].keys() )
    mass = f['TreeHalos']['Group_M_Crit200'][...]
    snap = f['TreeHalos']['SnapNum'][...]
# Out:
# <KeysViewHDF5 ['Config', 'Header', 'Parameters', 'TreeHalos', 'TreeTable', 'TreeTimes']>
# <KeysViewHDF5 ['Length', 'StartOffset', 'TreeID']>
# <HDF5 group "/TreeHalos" (26 members)>
# <KeysViewHDF5 ['GroupNr', 'Group_M_Crit200', 'SnapNum', 'SubhaloHalfmassRad', 'SubhaloIDMostbound', 'SubhaloLen', 'SubhaloLenType', 'SubhaloMass', 'SubhaloNr', 'SubhaloPos', 'SubhaloSpin', 'SubhaloVel', 'SubhaloVelDisp', 'SubhaloVmax', 'SubhaloVmaxRad', 'TreeDescendant', 'TreeFirstDescendant', 'TreeFirstHaloInFOFgroup', 'TreeFirstProgenitor', 'TreeID', 'TreeIndex', 'TreeMainProgenitor', 'TreeNextDescendant', 'TreeNextHaloInFOFgroup', 'TreeNextProgenitor', 'TreeProgenitor']>

# %%
tree_mem_14 = N_h * len(mass) * 26 * 3 * 4

# %%
tree_mem_14 / 1e9
# Out:
# 109.42748128
